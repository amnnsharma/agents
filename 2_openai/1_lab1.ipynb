# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model
# instructions are basically the system 
# you call different models other than open-ai's
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
result= Runner.run(agent, "Tell me a joke")
print(result)
# Out:
# <coroutine object Runner.run at 0x1076be8f0>

# %%
result= await Runner.run(agent, "Tell me a joke")
print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Jokester", ...)
# - Final output (str):
#     Why don't scientists trust atoms?
#
#     Because they make up everything!
# - 1 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)
# /var/folders/kv/fwt1l7t944ndvbwy1r6qftzr0000gn/T/ipykernel_16205/80504792.py:1: RuntimeWarning: coroutine 'Runner.run' was never awaited
#   result= await Runner.run(agent, "Tell me a joke")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
print(result.final_output)
# Out:
# Why don't scientists trust atoms?
#
# Because they make up everything!

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the Autonomous AI Agent bring a ladder to the bar?
#
# Because it heard the drinks were on the house!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ![image.png](attachment:image.png)
